# %%
import pandas as pd

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7829 entries, 0 to 7828
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  7829 non-null   object
#  1   timestamp       7829 non-null   object
#  2   product_id      7829 non-null   object
#  3   category        7829 non-null   object
#  4   customer_type   7829 non-null   object
#  5   unit_price      7829 non-null   float64
#  6   quantity        7829 non-null   int64
#  7   total           7829 non-null   float64
#  8   payment_type    7829 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 550.6+ KB

# %%
data.describe(include='all')
# Out:
#                               transaction_id            timestamp  \
# count                                   7829                 7829
# unique                                  7829                 7738
# top     a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 19:32:20
# freq                                       1                    2
# mean                                     NaN                  NaN
# std                                      NaN                  NaN
# min                                      NaN                  NaN
# 25%                                      NaN                  NaN
# 50%                                      NaN                  NaN
# 75%                                      NaN                  NaN
# max                                      NaN                  NaN
#
#                                   product_id category customer_type  \
# count                                   7829     7829          7829
# ...

# %%
data.isnull().sum()
# Out:
# transaction_id    0
# timestamp         0
# product_id        0
# category          0
# customer_type     0
# unit_price        0
# quantity          0
# total             0
# payment_type      0
# dtype: int64

# %%
data['customer_type'].unique().T
# Out:
# array(['gold', 'standard', 'premium', 'basic', 'non-member'], dtype=object)

# %%
data['customer_type'].value_counts()
# Out:
# non-member    1601
# standard      1595
# premium       1590
# basic         1526
# gold          1517
# Name: customer_type, dtype: int64

# %%
data["quantity"].unique()
# Out:
# array([2, 1, 4, 3])

# %%
data['quantity'].value_counts()
# Out:
# 1    1979
# 4    1976
# 3    1954
# 2    1920
# Name: quantity, dtype: int64

# %%
data_cols=data.columns

# %%
def stat(data_cols='x'):
    for i in data_cols:
      if i==x:
         x=data["category"].value_counts()
      print(x) 
      break 
      i==data['quantity'].value_counts()
      print(i)

# %%
def plot_continuous_distribution(data: pd.DataFrame = data, column: str = None, height: int = 8):
  _ = sns.displot(data, x=column, kde=True, height=height, aspect=height/5).set(title=f'Distribution of {column}');

# %%
import seaborn as sns

# %%
plot_continuous_distribution(data)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(10,5))
c= data.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#             unit_price  quantity     total
# unit_price    1.000000  0.024588  0.792018
# quantity      0.024588  1.000000  0.521926
# total         0.792018  0.521926  1.000000

# %%
def get_unique_values(data, column):
  num_unique_values = len(data[column].unique())
  value_counts = data[column].value_counts()
  print(f"Column: {column} has {num_unique_values} unique values\n")
  print(value_counts)

def plot_categorical_distribution(data: pd.DataFrame = data, column: str = None, height: int = 8, aspect: int = 2):
  _ = sns.catplot(data=data, x=data_cols, kind='count', height=height, aspect=aspect).set(title=f'Distribution of {column}');

def correlation_plot(data: pd.DataFrame = data):
  corr = data.corr()
  corr.style.background_gradient(cmap='coolwarm')

# %%
correlation_plot(data)

# %%
for col in data.columns:
    print(f"Features Name : {col}\n {data[col].unique()}\n\n")
# Out:
# Features Name : transaction_id
#  ['a1c82654-c52c-45b3-8ce8-4c2a1efe63ed'
#  '931ad550-09e8-4da6-beaa-8c9d17be9c60'
#  'ae133534-6f61-4cd6-b6b8-d1c1d8d90aea' ...
#  '79aee7d6-1405-4345-9a15-92541e9e1e74'
#  'e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55'
#  'afd70b4f-ee21-402d-8d8f-0d9e13c2bea6']
#
#
# Features Name : timestamp
#  ['2022-03-02 09:51:38' '2022-03-06 10:33:59' '2022-03-04 17:20:21' ...
#  '2022-03-03 14:00:09' '2022-03-04 15:11:38' '2022-03-06 13:50:36']
#
#
# Features Name : product_id
#  ['3bc6c1ea-0198-46de-9ffd-514ae3338713'
#  'ad81b46c-bf38-41cf-9b54-5fe7f5eba93e'
#  '7c55cbd4-f306-4c04-a030-628cbe7867c1'
#  '80da8348-1707-403f-8be7-9e6deeccc883'
#  '7f5e86e6-f06f-45f6-bf44-27b095c9ad1d'
#  '14736243-d346-438f-9535-d80fcb9f3882'
#  '0ddc2379-adba-4fb0-aa97-19fcafc738a1'
#  '35e00193-aa27-4121-87f4-6ac0d8a8671f'
#  'ecac012c-1dec-41d4-9ebd-56fb7166f6d9'
#  '04da844d-8dba-4470-9119-e534d52a03a0'
#  '68edf843-f13c-4ac8-bcf7-b3062266dbbb'
# ...
